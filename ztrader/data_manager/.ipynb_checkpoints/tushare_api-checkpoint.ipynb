# %% [markdown]
# 下载日线数据

# %%
# !pip install google
# !pip install qgrid
# Out:
# Looking in indexes: https://mirrors.cloud.tencent.com/pypi/simple
# ...
# [notice] A new release of pip available: 22.3.1 -> 23.0
# [notice] To update, run: C:\Users\Physi\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Looking in indexes: https://mirrors.cloud.tencent.com/pypi/simple
# ...
#      -------------------------------------- 889.2/889.2 kB 2.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Running setup.py install for qgrid: started
#   Running setup.py install for qgrid: finished with status 'done'
# ...

# %%
# TOKEN = '03631bc2224f99e4f1a2bd80c8c81983cbd0d4c313c0d337bbc3f124'
TOKEN='0b4d8d6fd5d5e5058e93a259a410f94f9f8b7279ab9247c9b81ac404'
# %load_ext google.colab.data_table
import qgrid
# Out:
# Looking in indexes: https://mirrors.cloud.tencent.com/pypi/simple
# ...
# [notice] A new release of pip available: 22.3.1 -> 23.0
# [notice] To update, run: C:\Users\Physi\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 4
#       2 TOKEN='0b4d8d6fd5d5e5058e93a259a410f94f9f8b7279ab9247c9b81ac404'
#       3 get_ipython().system('pip install google')
# ----> 4 get_ipython().run_line_magic('load_ext', 'google.colab.data_table')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\IPython\core\interactiveshell.py:2369, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2367     kwargs['local_ns'] = self.get_local_scope(stack_depth)
# ...

# %%
import tushare as ts

pro = ts.pro_api(TOKEN)

# %%
df = pro.daily(ts_code='000001.SZ,600000.SH', start_date='20180701', end_date='20180718')

# %%
df
# Out:
#       ts_code trade_date  open  high   low  close  pre_close  change  pct_chg  \
# 0   600000.SH   20180718  9.51  9.64  9.48   9.51       9.44    0.07     0.74
# 1   000001.SZ   20180718  8.75  8.85  8.69   8.70       8.72   -0.02    -0.23
# 2   000001.SZ   20180717  8.74  8.75  8.66   8.72       8.73   -0.01    -0.11
# 3   600000.SH   20180717  9.41  9.48  9.38   9.44       9.41    0.03     0.32
# 4   000001.SZ   20180716  8.85  8.90  8.69   8.73       8.88   -0.15    -1.69
# 5   600000.SH   20180716  9.50  9.54  9.34   9.41       9.49   -0.08    -0.84
# 6   600000.SH   20180713  9.57  9.58  9.46   9.49       9.47    0.02     0.21
# 7   000001.SZ   20180713  8.92  8.94  8.82   8.88       8.88    0.00     0.00
# 8   000001.SZ   20180712  8.60  8.97  8.58   8.88       8.64    0.24     2.78
# 9   600000.SH   20180712  9.41  9.61  9.39   9.57       9.38    0.19     2.03
# 10  000001.SZ   20180711  8.76  8.83  8.68   8.78       8.98   -0.20    -2.23
# ...

# %%
ts.set_token(TOKEN)

df = ts.pro_bar(ts_code='000001.SZ', adj='qfq', start_date='20180101', end_date='20181011', freq='15min')

df
# Out:
#         ts_code           trade_time     open    close     high      low  \
# 0     000001.SZ  2018-10-10 15:00:00  10.4100  10.4500  10.4500  10.3800
# 1     000001.SZ  2018-10-10 14:45:00  10.4300  10.4000  10.4500  10.4000
# 2     000001.SZ  2018-10-10 14:30:00  10.4700  10.4300  10.4700  10.3900
# 3     000001.SZ  2018-10-10 14:15:00  10.4800  10.4600  10.5200  10.4600
# 4     000001.SZ  2018-10-10 14:00:00  10.4700  10.4700  10.5100  10.4600
# ...         ...                  ...      ...      ...      ...      ...
# 3157  000001.SZ  2018-01-02 10:30:00  13.5013  13.6096  13.6588  13.5013
# 3158  000001.SZ  2018-01-02 10:15:00  13.6391  13.5111  13.6391  13.5013
# 3159  000001.SZ  2018-01-02 10:00:00  13.3439  13.6292  13.6784  13.3439
# 3160  000001.SZ  2018-01-02 09:45:00  13.1667  13.3340  13.4324  13.1077
# 3161  000001.SZ  2018-01-02 09:30:00  13.1372  13.1372  13.1372  13.1372
#
#              vol       amount
# 0      7823914.0   81440016.0
# ...

# %% [markdown]
# 交易日历

# %%
df = pro.trade_cal(exchange='', start_date='20090101', end_date='20181231')
df
# Out:
#      exchange  cal_date  is_open pretrade_date
# 0         SSE  20181231        0      20181228
# 1         SSE  20181230        0      20181228
# 2         SSE  20181229        0      20181228
# 3         SSE  20181228        1      20181227
# 4         SSE  20181227        1      20181226
# ...       ...       ...      ...           ...
# 3647      SSE  20090105        1      20081231
# 3648      SSE  20090104        0      20081231
# 3649      SSE  20090103        0      20081231
# 3650      SSE  20090102        0      20081231
# 3651      SSE  20090101        0      20081231
#
# [3652 rows x 4 columns]

# %% [markdown]
# 股票列表

# %%
data = pro.query('stock_basic', exchange='', list_status='L', fields='ts_code,symbol,name,area,industry,list_date')
data
# Out:
#         ts_code  symbol     name  area industry list_date
# 0     000001.SZ  000001     平安银行    深圳       银行  19910403
# 1     000002.SZ  000002      万科A    深圳     全国地产  19910129
# 2     000004.SZ  000004     ST国华    深圳     软件服务  19910114
# 3     000005.SZ  000005     ST星源    深圳     环境保护  19901210
# 4     000006.SZ  000006     深振业A    深圳     区域地产  19920427
# ...         ...     ...      ...   ...      ...       ...
# 5086  873223.BJ  873223     荣亿精密  None     None  20220609
# 5087  873305.BJ  873305     九菱科技  None     None  20221221
# 5088  873339.BJ  873339     恒太照明  None     None  20221117
# 5089  873527.BJ  873527      夜光明  None     None  20221027
# 5090  689009.SH  689009  九号公司-WD    北京      摩托车  20201029
#
# [5091 rows x 6 columns]

# %% [markdown]
# 复权因子

# %%
df = pro.adj_factor(ts_code='', trade_date='20180718')
df
# Out:
#         ts_code trade_date  adj_factor
# 0     000001.SZ   20180718     108.031
# 1     000002.SZ   20180718     137.300
# 2     000004.SZ   20180718       4.064
# 3     000005.SZ   20180718       9.268
# 4     000006.SZ   20180718      34.226
# ...         ...        ...         ...
# 3600  839729.BJ   20180718       1.048
# 3601  839946.BJ   20180718       1.027
# 3602  870436.BJ   20180718       1.000
# 3603  871396.BJ   20180718       1.094
# 3604  871642.BJ   20180718       1.000
#
# [3605 rows x 3 columns]

# %% [markdown]
# 停复牌信息

# %%
df = pro.suspend(ts_code='600848.SH', suspend_date='', resume_date='', fields='')
df
# Out:
#        ts_code suspend_date resume_date suspend_reason
# 0    600848.SH     20190327    20190328        重要事项未公告
# 1    600848.SH     20181009    20181010      拟筹划重大资产重组
# 2    600848.SH     20181008        None      拟筹划重大资产重组
# 3    600848.SH     20180928        None      拟筹划重大资产重组
# 4    600848.SH     20180927        None      拟筹划重大资产重组
# ..         ...          ...         ...            ...
# 522  600848.SH     20001226        None           关联交易
# 523  600848.SH     20001225        None         召开股东大会
# 524  600848.SH     20001215        None     关联交易评估结果公告
# 525  600848.SH     20000620        None         召开股东大会
# 526  600848.SH     19990625        None         召开股东大会
#
# [527 rows x 4 columns]

# %% [markdown]
# 每日停复牌信息

# %%
df = pro.suspend_d(suspend_type='S', trade_date='20200312')
df
# Out:
#       ts_code trade_date suspend_timing suspend_type
# 0   000029.SZ   20200312           None            S
# 1   000502.SZ   20200312           None            S
# 2   000977.SZ   20200312           None            S
# 3   002450.SZ   20200312           None            S
# 4   300592.SZ   20200312           None            S
# 5   300819.SZ   20200312    09:30-10:00            S
# 6   300821.SZ   20200312    09:30-10:00            S
# 7   600145.SH   20200312           None            S
# 8   600228.SH   20200312           None            S
# 9   600310.SH   20200312           None            S
# 10  600745.SH   20200312           None            S
# 11  600766.SH   20200312           None            S
# 12  600891.SH   20200312           None            S
# 13  601127.SH   20200312           None            S
# 14  601162.SH   20200312           None            S
# 15  603002.SH   20200312           None            S
# 16  603399.SH   20200312           None            S

# %% [markdown]
# 每日涨跌停价格

# %%
# df = pro.stk_limit(trade_date='20190625')
df = pro.stk_limit(ts_code='002149.SZ', start_date='20190115', end_date='20190615')
df
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[27], line 2
#       1 # df = pro.stk_limit(trade_date='20190625')
# ----> 2 df = pro.stk_limit(ts_code='002149.SZ', start_date='20190115', end_date='20190615')
#       3 df
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\tushare\pro\client.py:45, in DataApi.query(self, api_name, fields, **kwargs)
#      43 result = json.loads(res.text)
#      44 if result['code'] != 0:
# ---> 45     raise Exception(result['msg'])
#      46 data = result['data']
#      47 columns = data['fields']
#
# Exception: 抱歉，您没有访问该接口的权限，权限的具体详情访问：https://tushare.pro/document/1?doc_id=108。

# %% [markdown]
# 盘面指标
# turnover_rate
# turnover_rate_f
# volume_ratio
# pe
# pe_ttm
# pb
# free_share
# total_share
# total_mv
# circ_mv

# %%
df = pro.daily_basic(ts_code='', trade_date='20180726', fields='ts_code,trade_date,turnover_rate,volume_ratio,pe,pb')
df
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 df = pro.daily_basic(ts_code='', trade_date='20180726', fields='ts_code,trade_date,turnover_rate,volume_ratio,pe,pb')
#       2 df
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\tushare\pro\client.py:45, in DataApi.query(self, api_name, fields, **kwargs)
#      43 result = json.loads(res.text)
#      44 if result['code'] != 0:
# ---> 45     raise Exception(result['msg'])
#      46 data = result['data']
#      47 columns = data['fields']
#
# Exception: 抱歉，您没有访问该接口的权限，权限的具体详情访问：https://tushare.pro/document/1?doc_id=108。

# %% [markdown]
# 指数日线行情

# %%
pro = ts.pro_api()

df = pro.index_daily(ts_code='399300.SZ')

#或者按日期取

df = pro.index_daily(ts_code='399300.SZ', start_date='20180101', end_date='20181010')
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[29], line 3
#       1 pro = ts.pro_api()
# ----> 3 df = pro.index_daily(ts_code='399300.SZ')
#       5 #或者按日期取
#       7 df = pro.index_daily(ts_code='399300.SZ', start_date='20180101', end_date='20181010')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\tushare\pro\client.py:45, in DataApi.query(self, api_name, fields, **kwargs)
#      43 result = json.loads(res.text)
#      44 if result['code'] != 0:
# ---> 45     raise Exception(result['msg'])
#      46 data = result['data']
#      47 columns = data['fields']
#
# Exception: 抱歉，您没有访问该接口的权限，权限的具体详情访问：https://tushare.pro/document/1?doc_id=108。

# %% [markdown]
# 指数基本信息

# %%
pro = ts.pro_api()

df = pro.index_basic(category='行业指数')
df
# Out:
#         ts_code           name market publisher category base_date  \
# 0     000018.SH          180金融    SSE      中证公司     行业指数  20020628
# 1     399367.SZ         1000地产   SZSE       深交所     行业指数  20041231
# 2    930800.CSI  中国1000能源(CNY)    CSI      中证公司     行业指数  20061229
# 3    930801.CSI  中国1000材料(CNY)    CSI      中证公司     行业指数  20061229
# 4    930802.CSI  中国1000工业(CNY)    CSI      中证公司     行业指数  20061229
# ..          ...            ...    ...       ...      ...       ...
# 297  h21119.CSI   海外中国公用全(USD)    CSI      中证公司     行业指数  20141114
# 298   h40105.SH        上证证券全收益    SSE      中证公司     行业指数  20121231
# 299  n99302.CSI        三板制造全收益    CSI      中证公司     行业指数  20181220
# 300  n99303.CSI        三板服务全收益    CSI      中证公司     行业指数  20181220
# 301  n99304.CSI        三板医药全收益    CSI      中证公司     行业指数  20181220
#
#      base_point list_date
# 0        1000.0  20071210
# 1        1000.0  20091104
# 2        1000.0  20160510
# 3        1000.0  20160510
# ...
